# %% [markdown]
# # Submit your pdf report as well as your ipynb file to Avenue (separate files). Make sure your pdf report includes all the plots, results, and analyses.
#
#
# # SVM and Logistic Regression with PyTorch Implementation
# In this exercise, we explore a machine learning framework called PyTorch. We will use the framework to implement SVM and Logistic Regression models and address a multi-class image classification problem.
#
# # Submission
# - There are four tasks for you.
# - Report the results and answer the questions in a pdf file.
# - Additionally, submit your code in the same Jupiter notebook format. (keep the overal format of the notebook unchanged)

# %%
# Hyperparameters for training a neural network on the MNIST dataset

# Learning rate controls the step size of gradient descent, determining how much to update the weights in each iteration.
learning_rate = 0.02

# Number of epochs specifies how many complete passes through the training dataset will be performed.
num_epochs = 100

# Batch size defines the number of images processed in each mini-batch during training.
batch_size = 32

# Percentage of the dataset to be used for training, allowing for experimentation with smaller subsets of data.
train_data_percentage = 0.0025
test_data_percentage = 0.1

# Input size corresponds to the dimensions of the MNIST images, flattened from 28x28 pixels.
input_size = 28 * 28  # MNIST image size

# Number of output classes, representing the digits 0 through 9 in the MNIST dataset.
num_classes = 10  # Number of classes in MNIST

# %%
import torch
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# %% [markdown]
# # Dataset characteristics
# We use the MNIST digit classification data set for this assignment.
# A total of 60K images for training and 10K images for testing are available. But we only use a small percentage of them. Images are 28 x 28 pixels.

# %%
# Load MNIST datasets, and create pytorch data loader to read data in mini-batches
def get_data_loaders(train_data_percentage, test_data_percentage, batch_size, transform):
    # Load the entire MNIST dataset
    # For train and test data points we sometimes use different transforms.
    # This becomes handy in the last task (data augmentation)
    full_train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_transform = transforms.Compose([transforms.ToTensor()])
    full_test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=test_transform)

    # Calculate the size based on the percentage
    train_size = int(train_data_percentage * len(full_train_dataset))  # percentage of training data
    test_size = int(test_data_percentage * len(full_test_dataset))    # percentage of test data
    train_remainder = len(full_train_dataset) - train_size
    test_remainder = len(full_test_dataset) - test_size

    # Split the dataset into the percentage specified and the remaining
    train_dataset, _ = random_split(full_train_dataset, [train_size, train_remainder])
    test_dataset, _ = random_split(full_test_dataset, [test_size, test_remainder])

    # Create DataLoaders for batching and shuffling
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
# Define transformation (convert to tensor)
transform = transforms.Compose([transforms.ToTensor()])
train_loader, test_loader = get_data_loaders(train_data_percentage, test_data_percentage,batch_size, transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 54.0MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.87MB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 13.5MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.81MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# Get first batch of images and labels
train_image_batch, classe_set = next(iter(train_loader))

print(f'train_loader contains {len(train_loader)} batches of data.')
print(f'train_image_batch has shape {train_image_batch.shape},')
print('where 64 is the number of images in a batch, 1 is the number of image channels (1 for grayscale image),\
 28X28 stands for WxH (width and height of a single image).')
# Out:
# train_loader contains 5 batches of data.
# train_image_batch has shape torch.Size([32, 1, 28, 28]),
# where 64 is the number of images in a batch, 1 is the number of image channels (1 for grayscale image), 28X28 stands for WxH (width and height of a single image).

# %% [markdown]
# # Visualization of the dataset

# %%
def show_gray_digits(image_set, row=2, col=3):
    # Here we visualize some of the data points in the data set.
    # Create a large figure, to be filled with multiple subplots.

    # Since image_set is a tensor variable, we transform it to a numpy type variable.
    image_set = image_set.cpu().detach().numpy()

    for i in range(row*col):
      # define subplot
      plt.subplot(row, col, i+1)
      # plot raw pixel data
      plt.imshow(image_set[i,0], cmap=plt.get_cmap('gray'))
    # show the figure
    plt.show()

# %%
# display images and their corresponding labels.
show_gray_digits(train_image_batch, 2, 3)
print(classe_set[:6])

del train_image_batch, classe_set, train_loader, test_loader, transform
# Out:
# tensor([2, 6, 7, 3, 4, 8])

# %% [markdown]
# # Task 1: Linear SVM for MNIST classification (30 points).
# In this part, you are provided with the implementation of a multi-class linear SVM model and the basic MNIST classfication workflow. Run the given code and try to understand how it works.

# %% [markdown]
# ## Part A (5 points):
#
# Is the implementation of the multi-class linear SVM similar to the end-to-end multiclass SVM that we learned in the class? Are there any significant differences?

# %% [markdown]
# ## Part B (15 points):
# 1. Compute the accuracy on the train and test set after each epoch in the training. Plot these accuracies as a function of the epoch number and include it in the report (include only the plot in your report, not all the 2*100 numbers).
#
# 2. Compute the hinge loss on the train and test set after each epoch in the training. Plot these loss values as a function of the epoch number and include it in the report.(include only the plot in your report, not all the 2*100 numbers)
#
# 3. Report the **last** epoch results (including loss values and accuracies) for both train and test sets.
#
# 4. Does the model shows significant overfitting? Or do you think there might be other factors that are more significant in the mediocre performance of the model?

# %%
# Function to plot train/test loss and accuracy on separate subplots
def plot_eval_results(train_loss, test_loss, train_acc, test_acc):
    """
    Plots the training and testing loss/accuracy over the number of epochs.

    Parameters:
    - train_loss: list or array, the training loss values over epochs.
    - test_loss: list or array, the testing loss values over epochs.
    - train_acc: list or array, the training accuracy values over epochs.
    - test_acc: list or array, the testing accuracy values over epochs.
    """


    # Create subplots (1 row, 2 columns) for loss and accuracy
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # figsize sets the overall plot size

    # Plot Loss on the first subplot

    ax1.plot(train_loss, label='Train Loss')
    ax1.plot(test_loss, label='Test Loss')
    ax1.set_xlabel('Epoch Number')
    ax1.set_ylabel('Loss Value')
    ax1.set_title('Training / Test Loss per Epoch')
    ax1.legend()

    # Plot Accuracy on the second subplot

    ax2.plot(train_acc, label='Train Accuracy')
    ax2.plot(test_acc, label='Test Accuracy')
    ax2.set_xlabel('Epoch Value')
    ax2.set_ylabel('Accuracy')
    ax2.set_title('Training / Test Accuracy per Epoch')
    ax2.legend()

    # Adjust layout to avoid subplot overlap
    plt.tight_layout()

    # Display the plots
    plt.show()

# %%
# Define a linear SVM model
class LinearSVM(nn.Module):
    def __init__(self, input_size, num_classes):
        super(LinearSVM, self).__init__()
        self.fc = nn.Linear(input_size, num_classes, bias=True)

    def forward(self, x):
        # Flatten the image
        x= x.view(-1, input_size)
        return self.fc(x)

# %%
# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor()])
train_loader, test_loader = get_data_loaders(train_data_percentage, test_data_percentage, batch_size, transform)

# %%
# Return model loss and accuracy with the provided criterion and data_loader.
def eval(model, data_loader, criterion=None):
  model.eval()
  correct = 0
  total = 0
  loss_batches = []

  # Switch to evaluation mode and turn off gradient calculation
  # since parameters are not updated during testing.
  with torch.no_grad():
      for images_batch, labels_batch in data_loader:
          outputs = model(images_batch)
          # The predicted label is the output with the highest activation.
          _, predicted = torch.max(outputs.data, 1)
          total += labels_batch.size(0)
          correct += (predicted == labels_batch).sum().item()

          # Use provided criterion to calculate the loss for the mini batch
          # Append the mini-batch loss to loss_batches array
          batch_loss = criterion(outputs, labels_batch)
          loss_batches.append(batch_loss.item())

  accuracy = 100 * correct / total
  loss = np.mean(loss_batches)

  model.train()

  return accuracy, loss

# %%
# Initialize the model, loss function, and optimizer
model = LinearSVM(input_size, num_classes)
criterion = nn.MultiMarginLoss()  # A Multi-class version of Hinge loss
optimizer = optim.SGD(model.parameters(), lr=learning_rate)


train_loss_epochs = []
test_loss_epochs = []
train_accuracy_epochs = []
test_accuracy_epochs = []

# Training the model
for epoch in range(num_epochs):
    for i, (images_batch, labels_batch) in enumerate(train_loader):
        optimizer.zero_grad() # Clear the gradients
        outputs = model(images_batch) # Forward pass
        loss = criterion(outputs, labels_batch) # Calculate loss
        loss.backward() # Backward pass
        optimizer.step() # Update weights

    # Obtain train/test loss values and accuracies after each epoch
    train_accuracy, train_loss = eval(model, train_loader, criterion)
    test_accuracy, test_loss = eval(model, test_loader, criterion)

    print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_accuracy:.2f}%')
    print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_accuracy:.2f}%')
    print("-------------------------------------------------------------")

    train_loss_epochs.append(train_loss)
    test_loss_epochs.append(test_loss)
    train_accuracy_epochs.append(train_accuracy)
    test_accuracy_epochs.append(test_accuracy)
# Out:
# Epoch 01 - Train loss: 0.753753, Train accuracy: 30.67%
#          - Test loss: 0.808608, Test accuracy: 23.30%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 0.614244, Train accuracy: 44.67%
#          - Test loss: 0.712379, Test accuracy: 31.30%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 0.511494, Train accuracy: 44.00%
#          - Test loss: 0.632296, Test accuracy: 33.00%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 0.442812, Train accuracy: 52.00%
#          - Test loss: 0.564655, Test accuracy: 39.10%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 0.375590, Train accuracy: 56.00%
#          - Test loss: 0.506622, Test accuracy: 44.10%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 0.334720, Train accuracy: 60.00%
#          - Test loss: 0.460264, Test accuracy: 47.00%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 0.296101, Train accuracy: 64.00%
#          - Test loss: 0.418810, Test accuracy: 49.70%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 0.269973, Train accuracy: 68.67%
#          - Test loss: 0.386507, Test accuracy: 53.50%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 0.243648, Train accuracy: 70.00%
#          - Test loss: 0.363160, Test accuracy: 54.20%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 0.223268, Train accuracy: 76.67%
#          - Test loss: 0.342149, Test accuracy: 58.10%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 0.204861, Train accuracy: 80.67%
#          - Test loss: 0.325550, Test accuracy: 61.00%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 0.190698, Train accuracy: 82.67%
#          - Test loss: 0.309825, Test accuracy: 63.00%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 0.179589, Train accuracy: 83.33%
#          - Test loss: 0.297876, Test accuracy: 63.80%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 0.168935, Train accuracy: 85.33%
#          - Test loss: 0.285825, Test accuracy: 65.40%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 0.160819, Train accuracy: 88.67%
#          - Test loss: 0.276834, Test accuracy: 66.60%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 0.154182, Train accuracy: 88.00%
#          - Test loss: 0.270160, Test accuracy: 66.50%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.141473, Train accuracy: 88.67%
#          - Test loss: 0.264024, Test accuracy: 66.80%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.133033, Train accuracy: 88.67%
#          - Test loss: 0.258878, Test accuracy: 66.80%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.127502, Train accuracy: 88.67%
#          - Test loss: 0.253283, Test accuracy: 67.50%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.122845, Train accuracy: 90.67%
#          - Test loss: 0.246982, Test accuracy: 67.70%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.116804, Train accuracy: 90.67%
#          - Test loss: 0.243047, Test accuracy: 68.40%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.113509, Train accuracy: 90.00%
#          - Test loss: 0.239863, Test accuracy: 68.40%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.108120, Train accuracy: 90.00%
#          - Test loss: 0.236165, Test accuracy: 69.00%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.108078, Train accuracy: 90.67%
#          - Test loss: 0.232131, Test accuracy: 69.30%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.103672, Train accuracy: 90.67%
#          - Test loss: 0.229186, Test accuracy: 69.20%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.098706, Train accuracy: 90.00%
#          - Test loss: 0.226449, Test accuracy: 69.00%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.094202, Train accuracy: 90.67%
#          - Test loss: 0.223522, Test accuracy: 69.80%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.089610, Train accuracy: 92.00%
#          - Test loss: 0.221200, Test accuracy: 69.80%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.088788, Train accuracy: 92.67%
#          - Test loss: 0.219580, Test accuracy: 70.10%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.085769, Train accuracy: 94.00%
#          - Test loss: 0.217162, Test accuracy: 70.40%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.079497, Train accuracy: 95.33%
#          - Test loss: 0.215325, Test accuracy: 70.70%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.080016, Train accuracy: 95.33%
#          - Test loss: 0.213704, Test accuracy: 70.90%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.074880, Train accuracy: 96.00%
#          - Test loss: 0.212178, Test accuracy: 70.90%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.074282, Train accuracy: 95.33%
#          - Test loss: 0.210497, Test accuracy: 71.50%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.073928, Train accuracy: 96.00%
#          - Test loss: 0.208916, Test accuracy: 71.20%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.069031, Train accuracy: 95.33%
#          - Test loss: 0.207402, Test accuracy: 71.80%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.067472, Train accuracy: 96.67%
#          - Test loss: 0.205709, Test accuracy: 72.20%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.066075, Train accuracy: 96.67%
#          - Test loss: 0.204761, Test accuracy: 72.30%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.064925, Train accuracy: 96.00%
#          - Test loss: 0.204811, Test accuracy: 71.90%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.060841, Train accuracy: 96.67%
#          - Test loss: 0.203425, Test accuracy: 72.20%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.059993, Train accuracy: 97.33%
#          - Test loss: 0.202166, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.059541, Train accuracy: 97.33%
#          - Test loss: 0.201816, Test accuracy: 72.00%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.056448, Train accuracy: 98.00%
#          - Test loss: 0.200405, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.056858, Train accuracy: 98.00%
#          - Test loss: 0.199515, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.056869, Train accuracy: 98.00%
#          - Test loss: 0.198884, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.055726, Train accuracy: 98.00%
#          - Test loss: 0.198304, Test accuracy: 72.80%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.051946, Train accuracy: 98.00%
#          - Test loss: 0.197787, Test accuracy: 72.70%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.051829, Train accuracy: 98.00%
#          - Test loss: 0.196623, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.051444, Train accuracy: 98.67%
#          - Test loss: 0.195955, Test accuracy: 73.10%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.048631, Train accuracy: 98.67%
#          - Test loss: 0.195613, Test accuracy: 73.00%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.047836, Train accuracy: 98.67%
#          - Test loss: 0.194756, Test accuracy: 73.10%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.047274, Train accuracy: 98.67%
#          - Test loss: 0.194329, Test accuracy: 73.10%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.047102, Train accuracy: 98.67%
#          - Test loss: 0.193353, Test accuracy: 73.00%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.046125, Train accuracy: 99.33%
#          - Test loss: 0.192591, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.044320, Train accuracy: 99.33%
#          - Test loss: 0.192720, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.043345, Train accuracy: 99.33%
#          - Test loss: 0.192438, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.042502, Train accuracy: 99.33%
#          - Test loss: 0.191602, Test accuracy: 73.70%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.041540, Train accuracy: 99.33%
#          - Test loss: 0.191413, Test accuracy: 73.20%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.042311, Train accuracy: 99.33%
#          - Test loss: 0.191039, Test accuracy: 73.00%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.039483, Train accuracy: 99.33%
#          - Test loss: 0.190501, Test accuracy: 73.20%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.039046, Train accuracy: 99.33%
#          - Test loss: 0.189822, Test accuracy: 73.50%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.037737, Train accuracy: 99.33%
#          - Test loss: 0.189465, Test accuracy: 73.20%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.037574, Train accuracy: 99.33%
#          - Test loss: 0.188979, Test accuracy: 73.10%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.035950, Train accuracy: 99.33%
#          - Test loss: 0.188447, Test accuracy: 73.80%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.037288, Train accuracy: 99.33%
#          - Test loss: 0.188174, Test accuracy: 73.80%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.034937, Train accuracy: 99.33%
#          - Test loss: 0.187883, Test accuracy: 73.50%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.034565, Train accuracy: 99.33%
#          - Test loss: 0.187418, Test accuracy: 74.10%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.033892, Train accuracy: 99.33%
#          - Test loss: 0.186898, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.033154, Train accuracy: 99.33%
#          - Test loss: 0.187013, Test accuracy: 73.80%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.032654, Train accuracy: 99.33%
#          - Test loss: 0.186873, Test accuracy: 73.70%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.031965, Train accuracy: 99.33%
#          - Test loss: 0.186775, Test accuracy: 74.20%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.030705, Train accuracy: 99.33%
#          - Test loss: 0.186427, Test accuracy: 73.90%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.030381, Train accuracy: 99.33%
#          - Test loss: 0.185964, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.030578, Train accuracy: 99.33%
#          - Test loss: 0.185401, Test accuracy: 74.20%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.029602, Train accuracy: 99.33%
#          - Test loss: 0.185053, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.029357, Train accuracy: 99.33%
#          - Test loss: 0.184433, Test accuracy: 74.50%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.028911, Train accuracy: 99.33%
#          - Test loss: 0.184499, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.028440, Train accuracy: 99.33%
#          - Test loss: 0.184157, Test accuracy: 74.50%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.028377, Train accuracy: 99.33%
#          - Test loss: 0.183715, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.027556, Train accuracy: 99.33%
#          - Test loss: 0.183351, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.027308, Train accuracy: 99.33%
#          - Test loss: 0.183337, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.026872, Train accuracy: 99.33%
#          - Test loss: 0.183015, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.026807, Train accuracy: 99.33%
#          - Test loss: 0.182870, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.025983, Train accuracy: 99.33%
#          - Test loss: 0.182703, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.025405, Train accuracy: 99.33%
#          - Test loss: 0.182450, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.025055, Train accuracy: 99.33%
#          - Test loss: 0.182408, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.024575, Train accuracy: 99.33%
#          - Test loss: 0.182145, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.023926, Train accuracy: 99.33%
#          - Test loss: 0.182260, Test accuracy: 75.00%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.023697, Train accuracy: 99.33%
#          - Test loss: 0.182406, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.022684, Train accuracy: 99.33%
#          - Test loss: 0.181620, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.022646, Train accuracy: 99.33%
#          - Test loss: 0.181275, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.023011, Train accuracy: 99.33%
#          - Test loss: 0.181054, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.022788, Train accuracy: 99.33%
#          - Test loss: 0.181014, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.021677, Train accuracy: 99.33%
#          - Test loss: 0.180983, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.022397, Train accuracy: 99.33%
#          - Test loss: 0.180538, Test accuracy: 74.50%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.021840, Train accuracy: 99.33%
#          - Test loss: 0.180488, Test accuracy: 74.50%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.020283, Train accuracy: 99.33%
#          - Test loss: 0.180271, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.020428, Train accuracy: 99.33%
#          - Test loss: 0.179990, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.020914, Train accuracy: 99.33%
#          - Test loss: 0.179912, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.020349, Train accuracy: 99.33%
#          - Test loss: 0.179639, Test accuracy: 74.40%
# -------------------------------------------------------------

# %%
# Plotting
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %% [markdown]
# ## Part C (10 points):
#
# Weight decay works like regularization. Set weight decay to each of the values (0.1, 1, 10) during defining the SGD optimizer (see  [SGD optimizer documentation](https://pytorch.org/docs/stable/generated/torch.optim.SGD.html) for how to do that). Plot the train/test losses and accuracies per epoch. Also report the last epoch results (loss and accuracy for both train and test) . Does weight decay help in this case?Justify the results.

# %%
for weight_decay in [0.1, 1, 10]:

    lsvm = LinearSVM(input_size, num_classes)
    criterion = nn.MultiMarginLoss()
    lvsm_parameters = lsvm.parameters()
    optimizer = optim.SGD(lvsm_parameters, lr=learning_rate, weight_decay=weight_decay)

    train_loss_epochs = []
    test_loss_epochs = []

    train_accuracy_epochs = []
    test_accuracy_epochs = []

    for epoch in range(num_epochs):
        for i, (images_batch, labels_batch) in enumerate(train_loader):
            optimizer.zero_grad()
            outputs = lsvm(images_batch)

            loss = criterion(outputs, labels_batch)
            loss.backward()

            optimizer.step()

        train_accuracy, train_loss = eval(lsvm, train_loader, criterion)
        test_accuracy, test_loss = eval(lsvm, test_loader, criterion)

        train_loss_epochs.append(train_loss)
        test_loss_epochs.append(test_loss)

        train_accuracy_epochs.append(train_accuracy)
        test_accuracy_epochs.append(test_accuracy)

    # Plot accuracies
    print(f'For weight decay value {weight_decay}:')
    plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

    print(f"Last epoch results for weight decay: {weight_decay}")
    print(f"Train Loss: {train_loss_epochs[-1]}, Train Accuracy: {train_accuracy_epochs[-1]}%")
    print(f"Test Loss: {test_loss_epochs[-1]}, Test Accuracy: {test_accuracy_epochs[-1]}%")
# Out:
# For weight decay value 0.1:
# Last epoch results for weight decay: 0.1
# Train Loss: 0.05080733746290207, Train Accuracy: 99.33333333333333%
# Test Loss: 0.22863826993852854, Test Accuracy: 73.7%
# For weight decay value 1:
# Last epoch results for weight decay: 1
# Train Loss: 0.2701704204082489, Train Accuracy: 84.66666666666667%
# Test Loss: 0.38539077434688807, Test Accuracy: 62.8%
# For weight decay value 10:
# Last epoch results for weight decay: 10
# Train Loss: 0.742145574092865, Train Accuracy: 22.666666666666668%
# Test Loss: 0.79698664881289, Test Accuracy: 12.2%

# %% [markdown]
# # Task 2: Logistic Regression for MNIST classification  (20 points).
# In this part, you are asked to implement a logistic regression model for the same MNIST classfication problem.

# %% [markdown]
# ## Part A (5 points):
# Use Cross Entropy Loss (rather than Hinge Loss) to implement logistic regression.

# %% [markdown]
# ## Part B (10 points):
# 1. Compute the accuracy on the train and test set after each epoch in the training. Plot these accuracies as a function of the epoch number.
#
# 2. Compute the cross-entropy loss on the train and test set after each epoch in the training. Plot these loss values as a function of the epoch number.
#
# 3. Report the last epoch results (including loss values and accuracies) for both train and test sets.
#
# 4. Deos the model shows significant overfitting? Or do you think there might be other factors that are more significant in the mediocre performance of the model?

# %% [markdown]
# ## Part C (5 points)
#
# Compare the results with SVM model. Does it work better, worse, or similar?

# %%
# Logistic Regression model
class LogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):

        super(LogisticRegression, self).__init__()
        self.lin = nn.Linear(input_size, num_classes, bias=True)

    def forward(self, x):

        x = x.view(-1, input_size)
        return self.lin(x)

# %%
# Model initialization

lr = LogisticRegression(input_size, num_classes)
lr_parameters = lr.parameters()

optimizer = optim.SGD(lr_parameters, lr=learning_rate)
criterion = nn.CrossEntropyLoss()

train_loss_epochs = []
train_accuracy_epochs = []

test_loss_epochs = []
test_accuracy_epochs = []

# Train logistic regression model for MNIST classification

for epoch in range(num_epochs):
    for i, (images_batch, labels_batch) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = lr(images_batch)

        loss = criterion(outputs, labels_batch)
        loss.backward()

        optimizer.step()

    train_accuracy, train_loss = eval(lr, train_loader, criterion)
    test_accuracy, test_loss = eval(lr, test_loader, criterion)

    train_loss_epochs.append(train_loss)
    train_accuracy_epochs.append(train_accuracy)

    test_loss_epochs.append(test_loss)
    test_accuracy_epochs.append(test_accuracy)

print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_accuracy:.2f}%')
print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_accuracy:.2f}%')
print("-------------------------------------------------------------")
# Out:
# Epoch 100 - Train loss: 0.351169, Train accuracy: 98.67%
#          - Test loss: 0.816530, Test accuracy: 75.30%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %% [markdown]
# # Task 3: Non-linearity (30 points)

# %% [markdown]
# ## Part A (20 points):
#
# Add a hidden layer with 5000 neurons and a RELU layer for both logistic regression and SVM models in Task 1 and Task 2.
# 1. For both models, plot the train loss and the test loss.
# 2. For both models, plot the train and test accuracies.
# 3. For both models, report the loss and accuracy for both train and test sets.

# %% [markdown]
# ## Part B (10 Points):
#
# Compare the results with the linear model (without weight decay, to keep the comparison fair). Which approach works better? Why? Which appproach is more prone to overfitting? Explain your findings and justify it.

# %%
# Both the SVM and Logistic Regression models we have in Task 1 and 2
# can be changed to the ModifiedModel below.

# Modified model with added neurons and relu layer
class ModifiedModel(nn.Module):
    def __init__(self, input_size, num_classes):

        super(ModifiedModel, self).__init__()
        self.lin1 = nn.Linear(input_size, 5000, bias=True)
        self.relu = nn.ReLU()
        self.lin2 = nn.Linear(5000, num_classes, bias=True)

    def forward(self, x):

        x = x.view(-1, input_size)
        x = self.lin1(x)
        x = self.relu(x)
        x = self.lin2(x)
        return x

# %%
# Run the ModifiedModel with Hinge Loss (SVM)
# Model initialization

modifiedmodel = ModifiedModel(input_size, num_classes)
modifiedmodel_parameters = modifiedmodel.parameters()

optimizer = optim.SGD(modifiedmodel_parameters, lr=learning_rate)
criterion = nn.MultiMarginLoss()

train_loss_epochs = []
train_accuracy_epochs = []

test_loss_epochs = []
test_accuracy_epochs = []

# Training

for epoch in range(num_epochs):
  for i, (images_batch, labels_batch) in enumerate(train_loader):
    optimizer.zero_grad()
    outputs = modifiedmodel(images_batch)

    loss = criterion(outputs, labels_batch)
    loss.backward()

    optimizer.step()

  train_accuracy, train_loss = eval(modifiedmodel, train_loader, criterion)
  test_accuracy, test_loss = eval(modifiedmodel, test_loader, criterion)

  train_loss_epochs.append(train_loss)
  train_accuracy_epochs.append(train_accuracy)

  test_loss_epochs.append(test_loss)
  test_accuracy_epochs.append(test_accuracy)

  print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_accuracy:.2f}%')
  print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_accuracy:.2f}%')
  print("-------------------------------------------------------------")
# Out:
# Epoch 01 - Train loss: 0.746800, Train accuracy: 16.00%
#          - Test loss: 0.812128, Test accuracy: 11.00%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 0.625184, Train accuracy: 30.00%
#          - Test loss: 0.732321, Test accuracy: 20.80%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 0.548834, Train accuracy: 46.00%
#          - Test loss: 0.662972, Test accuracy: 33.10%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 0.473616, Train accuracy: 52.00%
#          - Test loss: 0.602101, Test accuracy: 35.30%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 0.406362, Train accuracy: 61.33%
#          - Test loss: 0.536832, Test accuracy: 45.60%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 0.348104, Train accuracy: 73.33%
#          - Test loss: 0.482401, Test accuracy: 55.90%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 0.303643, Train accuracy: 74.00%
#          - Test loss: 0.435753, Test accuracy: 58.10%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 0.264624, Train accuracy: 82.00%
#          - Test loss: 0.393263, Test accuracy: 61.20%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 0.236295, Train accuracy: 86.00%
#          - Test loss: 0.363492, Test accuracy: 64.10%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 0.218291, Train accuracy: 88.67%
#          - Test loss: 0.338505, Test accuracy: 65.70%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 0.188395, Train accuracy: 88.00%
#          - Test loss: 0.321810, Test accuracy: 64.50%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 0.175332, Train accuracy: 90.00%
#          - Test loss: 0.303347, Test accuracy: 67.80%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 0.159161, Train accuracy: 89.33%
#          - Test loss: 0.290943, Test accuracy: 66.40%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 0.146130, Train accuracy: 92.67%
#          - Test loss: 0.275154, Test accuracy: 69.80%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 0.138024, Train accuracy: 92.67%
#          - Test loss: 0.267187, Test accuracy: 68.60%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 0.122527, Train accuracy: 92.00%
#          - Test loss: 0.261501, Test accuracy: 67.80%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.116103, Train accuracy: 94.67%
#          - Test loss: 0.250061, Test accuracy: 71.70%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.104838, Train accuracy: 94.67%
#          - Test loss: 0.245033, Test accuracy: 71.90%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.102858, Train accuracy: 96.00%
#          - Test loss: 0.236103, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.093994, Train accuracy: 95.33%
#          - Test loss: 0.233541, Test accuracy: 73.50%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.088750, Train accuracy: 95.33%
#          - Test loss: 0.229254, Test accuracy: 73.10%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.092386, Train accuracy: 96.67%
#          - Test loss: 0.224674, Test accuracy: 75.90%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.078297, Train accuracy: 96.67%
#          - Test loss: 0.221466, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.075508, Train accuracy: 96.00%
#          - Test loss: 0.219068, Test accuracy: 74.20%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.072686, Train accuracy: 97.33%
#          - Test loss: 0.215856, Test accuracy: 75.40%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.068091, Train accuracy: 97.33%
#          - Test loss: 0.213118, Test accuracy: 74.90%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.069195, Train accuracy: 97.33%
#          - Test loss: 0.210524, Test accuracy: 75.10%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.060724, Train accuracy: 98.00%
#          - Test loss: 0.208483, Test accuracy: 75.30%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.058814, Train accuracy: 98.00%
#          - Test loss: 0.206468, Test accuracy: 75.70%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.055704, Train accuracy: 98.00%
#          - Test loss: 0.203238, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.052285, Train accuracy: 98.67%
#          - Test loss: 0.203048, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.051362, Train accuracy: 98.67%
#          - Test loss: 0.202459, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.047199, Train accuracy: 98.00%
#          - Test loss: 0.200519, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.045278, Train accuracy: 98.67%
#          - Test loss: 0.199053, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.043945, Train accuracy: 99.33%
#          - Test loss: 0.197640, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.043143, Train accuracy: 99.33%
#          - Test loss: 0.195997, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.041339, Train accuracy: 99.33%
#          - Test loss: 0.195382, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.039717, Train accuracy: 99.33%
#          - Test loss: 0.194494, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.037527, Train accuracy: 99.33%
#          - Test loss: 0.193610, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.035529, Train accuracy: 99.33%
#          - Test loss: 0.192164, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.035122, Train accuracy: 99.33%
#          - Test loss: 0.191578, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.032236, Train accuracy: 99.33%
#          - Test loss: 0.191659, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.032231, Train accuracy: 99.33%
#          - Test loss: 0.189419, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.030709, Train accuracy: 99.33%
#          - Test loss: 0.189558, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.029975, Train accuracy: 99.33%
#          - Test loss: 0.189360, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.029141, Train accuracy: 99.33%
#          - Test loss: 0.188756, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.027857, Train accuracy: 99.33%
#          - Test loss: 0.188141, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.027719, Train accuracy: 99.33%
#          - Test loss: 0.187188, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.025746, Train accuracy: 99.33%
#          - Test loss: 0.186209, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.024881, Train accuracy: 99.33%
#          - Test loss: 0.185790, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.024254, Train accuracy: 99.33%
#          - Test loss: 0.186170, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.023753, Train accuracy: 99.33%
#          - Test loss: 0.185159, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.022862, Train accuracy: 99.33%
#          - Test loss: 0.184805, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.021789, Train accuracy: 99.33%
#          - Test loss: 0.184397, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.020978, Train accuracy: 99.33%
#          - Test loss: 0.184223, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.021020, Train accuracy: 99.33%
#          - Test loss: 0.183709, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.020167, Train accuracy: 99.33%
#          - Test loss: 0.182928, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.019118, Train accuracy: 99.33%
#          - Test loss: 0.181647, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.019513, Train accuracy: 99.33%
#          - Test loss: 0.181444, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.018593, Train accuracy: 99.33%
#          - Test loss: 0.181571, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.018204, Train accuracy: 99.33%
#          - Test loss: 0.180792, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.017564, Train accuracy: 99.33%
#          - Test loss: 0.181612, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.017309, Train accuracy: 99.33%
#          - Test loss: 0.180284, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.016901, Train accuracy: 99.33%
#          - Test loss: 0.180985, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.015919, Train accuracy: 99.33%
#          - Test loss: 0.180019, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.015551, Train accuracy: 99.33%
#          - Test loss: 0.179331, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.015106, Train accuracy: 99.33%
#          - Test loss: 0.179237, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.014996, Train accuracy: 99.33%
#          - Test loss: 0.178834, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.014287, Train accuracy: 99.33%
#          - Test loss: 0.178223, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.014101, Train accuracy: 99.33%
#          - Test loss: 0.178405, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.013625, Train accuracy: 99.33%
#          - Test loss: 0.177701, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.012554, Train accuracy: 99.33%
#          - Test loss: 0.177428, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.013431, Train accuracy: 99.33%
#          - Test loss: 0.177372, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.012666, Train accuracy: 99.33%
#          - Test loss: 0.176833, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.012005, Train accuracy: 99.33%
#          - Test loss: 0.177055, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.012325, Train accuracy: 99.33%
#          - Test loss: 0.176276, Test accuracy: 78.90%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.012024, Train accuracy: 99.33%
#          - Test loss: 0.176222, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.011206, Train accuracy: 99.33%
#          - Test loss: 0.176336, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.010840, Train accuracy: 100.00%
#          - Test loss: 0.175692, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.010448, Train accuracy: 100.00%
#          - Test loss: 0.175534, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.010216, Train accuracy: 100.00%
#          - Test loss: 0.175054, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.009960, Train accuracy: 100.00%
#          - Test loss: 0.175078, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.009303, Train accuracy: 100.00%
#          - Test loss: 0.174776, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.009315, Train accuracy: 100.00%
#          - Test loss: 0.174574, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.009501, Train accuracy: 100.00%
#          - Test loss: 0.174395, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.008587, Train accuracy: 100.00%
#          - Test loss: 0.174235, Test accuracy: 78.90%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.008751, Train accuracy: 100.00%
#          - Test loss: 0.173816, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.008181, Train accuracy: 100.00%
#          - Test loss: 0.173421, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.008058, Train accuracy: 100.00%
#          - Test loss: 0.173638, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.008055, Train accuracy: 100.00%
#          - Test loss: 0.173282, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.007923, Train accuracy: 100.00%
#          - Test loss: 0.173248, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.007413, Train accuracy: 100.00%
#          - Test loss: 0.173010, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.007313, Train accuracy: 100.00%
#          - Test loss: 0.172994, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.006929, Train accuracy: 100.00%
#          - Test loss: 0.172824, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.007447, Train accuracy: 100.00%
#          - Test loss: 0.172576, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.007095, Train accuracy: 100.00%
#          - Test loss: 0.172733, Test accuracy: 78.90%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.006665, Train accuracy: 100.00%
#          - Test loss: 0.172643, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.006576, Train accuracy: 100.00%
#          - Test loss: 0.172509, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.006029, Train accuracy: 100.00%
#          - Test loss: 0.172036, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.005953, Train accuracy: 100.00%
#          - Test loss: 0.171863, Test accuracy: 79.00%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %%
# Run the ModifiedModel with Cross Entropy Loss (Logistic Regression)
# Model initialization

modifiedmodel = ModifiedModel(input_size, num_classes)
modifiedmodel_parameters = modifiedmodel.parameters()

optimizer = optim.SGD(modifiedmodel_parameters, lr=learning_rate)
criterion = nn.CrossEntropyLoss()

train_loss_epochs = []
train_accuracy_epochs = []

test_loss_epochs = []
test_accuracy_epochs = []

# Training

for epoch in range(num_epochs):
    for i, (images_batch, labels_batch) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = modifiedmodel(images_batch)

        loss = criterion(outputs, labels_batch)
        loss.backward()

        optimizer.step()

    train_accuracy, train_loss = eval(modifiedmodel, train_loader, criterion)
    test_accuracy, test_loss = eval(modifiedmodel, test_loader, criterion)

    train_loss_epochs.append(train_loss)
    train_accuracy_epochs.append(train_accuracy)

    test_loss_epochs.append(test_loss)
    test_accuracy_epochs.append(test_accuracy)

    print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_accuracy:.2f}%')
    print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_accuracy:.2f}%')
    print("-------------------------------------------------------------")
# Out:
# Epoch 01 - Train loss: 2.184825, Train accuracy: 30.67%
#          - Test loss: 2.241006, Test accuracy: 20.20%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 2.084050, Train accuracy: 37.33%
#          - Test loss: 2.175646, Test accuracy: 24.50%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 1.990492, Train accuracy: 45.33%
#          - Test loss: 2.108753, Test accuracy: 32.60%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 1.898865, Train accuracy: 54.00%
#          - Test loss: 2.041167, Test accuracy: 41.10%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 1.819210, Train accuracy: 56.00%
#          - Test loss: 1.979373, Test accuracy: 41.10%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 1.725839, Train accuracy: 65.33%
#          - Test loss: 1.907192, Test accuracy: 50.80%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 1.645432, Train accuracy: 64.00%
#          - Test loss: 1.849508, Test accuracy: 50.80%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 1.574926, Train accuracy: 66.00%
#          - Test loss: 1.792053, Test accuracy: 52.50%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 1.507585, Train accuracy: 66.67%
#          - Test loss: 1.742132, Test accuracy: 53.10%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 1.434022, Train accuracy: 78.00%
#          - Test loss: 1.678480, Test accuracy: 55.20%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 1.372393, Train accuracy: 80.00%
#          - Test loss: 1.623572, Test accuracy: 56.90%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 1.299475, Train accuracy: 80.67%
#          - Test loss: 1.578303, Test accuracy: 58.40%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 1.258315, Train accuracy: 80.00%
#          - Test loss: 1.528878, Test accuracy: 60.00%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 1.191692, Train accuracy: 83.33%
#          - Test loss: 1.480772, Test accuracy: 61.90%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 1.142825, Train accuracy: 83.33%
#          - Test loss: 1.438061, Test accuracy: 62.20%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 1.103632, Train accuracy: 84.00%
#          - Test loss: 1.404112, Test accuracy: 62.70%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 1.047658, Train accuracy: 84.67%
#          - Test loss: 1.363010, Test accuracy: 63.90%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 1.016256, Train accuracy: 86.67%
#          - Test loss: 1.328982, Test accuracy: 65.20%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.967912, Train accuracy: 88.67%
#          - Test loss: 1.289191, Test accuracy: 66.80%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.938727, Train accuracy: 92.00%
#          - Test loss: 1.255625, Test accuracy: 68.50%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.894132, Train accuracy: 90.00%
#          - Test loss: 1.233562, Test accuracy: 68.70%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.855009, Train accuracy: 90.00%
#          - Test loss: 1.210800, Test accuracy: 66.80%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.826265, Train accuracy: 92.00%
#          - Test loss: 1.179688, Test accuracy: 69.20%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.797292, Train accuracy: 92.00%
#          - Test loss: 1.156378, Test accuracy: 69.80%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.767008, Train accuracy: 92.00%
#          - Test loss: 1.130481, Test accuracy: 71.00%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.747644, Train accuracy: 92.67%
#          - Test loss: 1.109785, Test accuracy: 72.00%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.723162, Train accuracy: 93.33%
#          - Test loss: 1.094650, Test accuracy: 70.60%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.705353, Train accuracy: 94.00%
#          - Test loss: 1.068351, Test accuracy: 72.40%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.664220, Train accuracy: 93.33%
#          - Test loss: 1.055101, Test accuracy: 71.40%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.640036, Train accuracy: 93.33%
#          - Test loss: 1.038414, Test accuracy: 71.50%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.633184, Train accuracy: 95.33%
#          - Test loss: 1.018591, Test accuracy: 72.20%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.605004, Train accuracy: 95.33%
#          - Test loss: 1.000772, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.599273, Train accuracy: 95.33%
#          - Test loss: 0.991318, Test accuracy: 72.80%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.573506, Train accuracy: 95.33%
#          - Test loss: 0.972093, Test accuracy: 73.80%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.560292, Train accuracy: 96.00%
#          - Test loss: 0.963968, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.540743, Train accuracy: 95.33%
#          - Test loss: 0.949708, Test accuracy: 73.90%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.520228, Train accuracy: 95.33%
#          - Test loss: 0.933545, Test accuracy: 74.50%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.516481, Train accuracy: 96.67%
#          - Test loss: 0.927934, Test accuracy: 72.80%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.504446, Train accuracy: 96.67%
#          - Test loss: 0.918523, Test accuracy: 73.70%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.486491, Train accuracy: 97.33%
#          - Test loss: 0.906621, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.469940, Train accuracy: 97.33%
#          - Test loss: 0.896874, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.457445, Train accuracy: 98.00%
#          - Test loss: 0.887934, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.439811, Train accuracy: 98.00%
#          - Test loss: 0.877696, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.429760, Train accuracy: 98.00%
#          - Test loss: 0.872754, Test accuracy: 74.50%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.422987, Train accuracy: 98.00%
#          - Test loss: 0.861407, Test accuracy: 75.40%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.416289, Train accuracy: 98.00%
#          - Test loss: 0.856252, Test accuracy: 75.00%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.392171, Train accuracy: 98.00%
#          - Test loss: 0.851298, Test accuracy: 74.90%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.392525, Train accuracy: 98.00%
#          - Test loss: 0.842311, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.387866, Train accuracy: 98.67%
#          - Test loss: 0.835777, Test accuracy: 75.80%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.366741, Train accuracy: 98.67%
#          - Test loss: 0.830944, Test accuracy: 75.50%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.359421, Train accuracy: 98.67%
#          - Test loss: 0.829587, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.355569, Train accuracy: 98.67%
#          - Test loss: 0.822174, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.340907, Train accuracy: 98.67%
#          - Test loss: 0.818654, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.334109, Train accuracy: 99.33%
#          - Test loss: 0.809106, Test accuracy: 75.20%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.321787, Train accuracy: 100.00%
#          - Test loss: 0.801616, Test accuracy: 75.70%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.316153, Train accuracy: 100.00%
#          - Test loss: 0.796321, Test accuracy: 75.80%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.309004, Train accuracy: 99.33%
#          - Test loss: 0.796631, Test accuracy: 75.30%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.311912, Train accuracy: 100.00%
#          - Test loss: 0.790735, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.295035, Train accuracy: 100.00%
#          - Test loss: 0.786510, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.297426, Train accuracy: 100.00%
#          - Test loss: 0.782653, Test accuracy: 75.40%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.289101, Train accuracy: 100.00%
#          - Test loss: 0.777625, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.277192, Train accuracy: 100.00%
#          - Test loss: 0.776863, Test accuracy: 75.00%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.275849, Train accuracy: 100.00%
#          - Test loss: 0.772137, Test accuracy: 75.30%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.267112, Train accuracy: 100.00%
#          - Test loss: 0.772249, Test accuracy: 75.40%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.265280, Train accuracy: 100.00%
#          - Test loss: 0.763430, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.255231, Train accuracy: 100.00%
#          - Test loss: 0.761083, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.254598, Train accuracy: 100.00%
#          - Test loss: 0.755500, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.249921, Train accuracy: 100.00%
#          - Test loss: 0.755035, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.246360, Train accuracy: 100.00%
#          - Test loss: 0.751740, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.235174, Train accuracy: 100.00%
#          - Test loss: 0.745397, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.235684, Train accuracy: 100.00%
#          - Test loss: 0.748374, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.225719, Train accuracy: 100.00%
#          - Test loss: 0.746803, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.221385, Train accuracy: 100.00%
#          - Test loss: 0.743537, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.220169, Train accuracy: 100.00%
#          - Test loss: 0.742870, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.211358, Train accuracy: 100.00%
#          - Test loss: 0.739215, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.210505, Train accuracy: 100.00%
#          - Test loss: 0.738369, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.206152, Train accuracy: 100.00%
#          - Test loss: 0.733407, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.200668, Train accuracy: 100.00%
#          - Test loss: 0.732153, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.198527, Train accuracy: 100.00%
#          - Test loss: 0.731208, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.192336, Train accuracy: 100.00%
#          - Test loss: 0.728799, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.191239, Train accuracy: 100.00%
#          - Test loss: 0.730196, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.187438, Train accuracy: 100.00%
#          - Test loss: 0.724645, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.183291, Train accuracy: 100.00%
#          - Test loss: 0.722531, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.180132, Train accuracy: 100.00%
#          - Test loss: 0.720425, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.180368, Train accuracy: 100.00%
#          - Test loss: 0.716481, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.172968, Train accuracy: 100.00%
#          - Test loss: 0.714389, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.171597, Train accuracy: 100.00%
#          - Test loss: 0.712158, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.169762, Train accuracy: 100.00%
#          - Test loss: 0.712424, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.169694, Train accuracy: 100.00%
#          - Test loss: 0.712817, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.168417, Train accuracy: 100.00%
#          - Test loss: 0.713123, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.157493, Train accuracy: 100.00%
#          - Test loss: 0.710690, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.156704, Train accuracy: 100.00%
#          - Test loss: 0.710572, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.158010, Train accuracy: 100.00%
#          - Test loss: 0.708076, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.155339, Train accuracy: 100.00%
#          - Test loss: 0.707466, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.152289, Train accuracy: 100.00%
#          - Test loss: 0.706708, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.147300, Train accuracy: 100.00%
#          - Test loss: 0.706271, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.145244, Train accuracy: 100.00%
#          - Test loss: 0.702058, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.148574, Train accuracy: 100.00%
#          - Test loss: 0.700847, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.142040, Train accuracy: 100.00%
#          - Test loss: 0.700218, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.137594, Train accuracy: 100.00%
#          - Test loss: 0.701027, Test accuracy: 76.70%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %% [markdown]
# # Task 4: Data Augmentation (20 points)
#
# In this task, we will explore the concept of data augmentation, which is a powerful technique used to enhance the diversity of our training dataset without collecting new data. By applying various transformations to the original training images, we can create modified versions of these images.
# We can then use these modified images to train our model with a "richer" set of examples.The use of data augmentation helps to improve the robustness and generalization of our models. Data augmentation is particularly beneficial in tasks like image classification, where we expect the model to be invariant to slight variations of images (e.g., rotation, cropping, blurring, etc.)
#
# For this task, you are given a code that uses Gaussian Blur augmentation, which applies a Gaussian filter to slightly blur the images. If you run the code, you will see that this type of augmentation actually makes the model less accurate (compared with Task 3, SVM test accuracy)
#
# For this task, you must explore other types of data augmentation and find one that improves the test accuracy by at least 1 percent compared with not using any augmentation (i.e., compared with Task 3, SVM test accuracy). Only change the augmentation approach, and keep the other parts of the code unchanged. Read the PyTorch documentation on different augmentation techniques [here](https://pytorch.org/vision/stable/transforms.html), and then try to identify a good augmentation method from them. Report the augmentation approach that you used, and explain why you think it helps. Also include train/test accuracy plots per epoch, and the train/test accuracy at the final epoch.
#
#
# Even if you find that your method does not improve upon the previous task, submit whatever you have completed to get partial marks.

# %%
# TRANSFOMATION
transform = transforms.Compose([
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomRotation(degrees=5),
    transforms.RandomHorizontalFlip(p=0.2),
    transforms.ToTensor()
])
train_loader_2, test_loader_2 = get_data_loaders(train_data_percentage, test_data_percentage, batch_size, transform)

# %%
# Run the ModifiedModel with Hinge Loss (SVM)
# Model initialization

modifiedmodel = ModifiedModel(input_size, num_classes)
modifiedmodel_parameters = modifiedmodel.parameters()

optimizer = optim.SGD(modifiedmodel_parameters, lr=learning_rate)
criterion = nn.MultiMarginLoss()

train_loss_epochs = []
train_accuracy_epochs = []

test_loss_epochs = []
test_accuracy_epochs = []

# Training

for epoch in range(num_epochs):
  for i, (images_batch, labels_batch) in enumerate(train_loader_2):
    optimizer.zero_grad()
    outputs = modifiedmodel(images_batch)

    loss = criterion(outputs, labels_batch)
    loss.backward()

    optimizer.step()

  train_accuracy, train_loss = eval(modifiedmodel, train_loader_2, criterion)
  test_accuracy, test_loss = eval(modifiedmodel, test_loader_2, criterion)

  train_loss_epochs.append(train_loss)
  train_accuracy_epochs.append(train_accuracy)

  test_loss_epochs.append(test_loss)
  test_accuracy_epochs.append(test_accuracy)

  print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_accuracy:.2f}%')
  print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_accuracy:.2f}%')
  print("-------------------------------------------------------------")
# Out:
# Epoch 01 - Train loss: 0.803400, Train accuracy: 32.00%
#          - Test loss: 0.810683, Test accuracy: 31.30%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 0.693120, Train accuracy: 41.33%
#          - Test loss: 0.723776, Test accuracy: 37.40%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 0.611162, Train accuracy: 44.67%
#          - Test loss: 0.653311, Test accuracy: 41.80%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 0.550535, Train accuracy: 48.67%
#          - Test loss: 0.586532, Test accuracy: 43.60%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 0.484474, Train accuracy: 56.00%
#          - Test loss: 0.523980, Test accuracy: 48.80%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 0.436031, Train accuracy: 62.00%
#          - Test loss: 0.470491, Test accuracy: 54.50%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 0.383750, Train accuracy: 64.00%
#          - Test loss: 0.423520, Test accuracy: 60.60%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 0.338820, Train accuracy: 69.33%
#          - Test loss: 0.386541, Test accuracy: 61.00%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 0.314260, Train accuracy: 70.00%
#          - Test loss: 0.353878, Test accuracy: 63.80%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 0.294289, Train accuracy: 72.67%
#          - Test loss: 0.331262, Test accuracy: 64.50%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 0.262461, Train accuracy: 76.67%
#          - Test loss: 0.307165, Test accuracy: 67.50%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 0.246233, Train accuracy: 78.00%
#          - Test loss: 0.289495, Test accuracy: 68.20%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 0.219645, Train accuracy: 80.67%
#          - Test loss: 0.274449, Test accuracy: 70.20%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 0.208517, Train accuracy: 80.67%
#          - Test loss: 0.260875, Test accuracy: 69.90%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 0.200074, Train accuracy: 83.33%
#          - Test loss: 0.243364, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 0.187687, Train accuracy: 83.33%
#          - Test loss: 0.237046, Test accuracy: 71.80%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.163958, Train accuracy: 84.67%
#          - Test loss: 0.226315, Test accuracy: 72.40%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.183950, Train accuracy: 82.00%
#          - Test loss: 0.220765, Test accuracy: 72.20%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.176988, Train accuracy: 81.33%
#          - Test loss: 0.214463, Test accuracy: 72.50%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.165026, Train accuracy: 83.33%
#          - Test loss: 0.208802, Test accuracy: 73.00%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.164632, Train accuracy: 80.67%
#          - Test loss: 0.205780, Test accuracy: 72.70%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.130240, Train accuracy: 87.33%
#          - Test loss: 0.200592, Test accuracy: 73.60%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.132813, Train accuracy: 87.33%
#          - Test loss: 0.195602, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.141818, Train accuracy: 85.33%
#          - Test loss: 0.193130, Test accuracy: 73.80%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.126258, Train accuracy: 88.67%
#          - Test loss: 0.188967, Test accuracy: 74.00%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.129196, Train accuracy: 86.00%
#          - Test loss: 0.185398, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.129377, Train accuracy: 84.00%
#          - Test loss: 0.181533, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.109251, Train accuracy: 87.33%
#          - Test loss: 0.178883, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.112049, Train accuracy: 87.33%
#          - Test loss: 0.176255, Test accuracy: 75.40%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.107471, Train accuracy: 88.67%
#          - Test loss: 0.174078, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.116029, Train accuracy: 85.33%
#          - Test loss: 0.171608, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.098176, Train accuracy: 92.00%
#          - Test loss: 0.170372, Test accuracy: 75.90%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.117973, Train accuracy: 88.67%
#          - Test loss: 0.168569, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.097832, Train accuracy: 88.67%
#          - Test loss: 0.166838, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.103276, Train accuracy: 90.00%
#          - Test loss: 0.164169, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.098446, Train accuracy: 88.67%
#          - Test loss: 0.162495, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.092455, Train accuracy: 89.33%
#          - Test loss: 0.160886, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.089621, Train accuracy: 90.00%
#          - Test loss: 0.158468, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.095062, Train accuracy: 87.33%
#          - Test loss: 0.157784, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.080807, Train accuracy: 89.33%
#          - Test loss: 0.158825, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.088299, Train accuracy: 89.33%
#          - Test loss: 0.156010, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.088734, Train accuracy: 89.33%
#          - Test loss: 0.154966, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.086166, Train accuracy: 90.00%
#          - Test loss: 0.154253, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.075816, Train accuracy: 90.67%
#          - Test loss: 0.153368, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.083036, Train accuracy: 88.67%
#          - Test loss: 0.152592, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.081383, Train accuracy: 89.33%
#          - Test loss: 0.151186, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.073355, Train accuracy: 92.00%
#          - Test loss: 0.149169, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.075662, Train accuracy: 90.00%
#          - Test loss: 0.148305, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.075593, Train accuracy: 90.00%
#          - Test loss: 0.148844, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.074676, Train accuracy: 88.00%
#          - Test loss: 0.148616, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.071589, Train accuracy: 92.67%
#          - Test loss: 0.146385, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.064360, Train accuracy: 90.67%
#          - Test loss: 0.145141, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.088037, Train accuracy: 88.00%
#          - Test loss: 0.144844, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.075062, Train accuracy: 89.33%
#          - Test loss: 0.144794, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.071556, Train accuracy: 91.33%
#          - Test loss: 0.143666, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.065909, Train accuracy: 89.33%
#          - Test loss: 0.142992, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.067794, Train accuracy: 90.67%
#          - Test loss: 0.143529, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.061990, Train accuracy: 92.00%
#          - Test loss: 0.142598, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.069470, Train accuracy: 91.33%
#          - Test loss: 0.142654, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.064341, Train accuracy: 92.00%
#          - Test loss: 0.141633, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.061716, Train accuracy: 94.67%
#          - Test loss: 0.140690, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.061859, Train accuracy: 92.00%
#          - Test loss: 0.140984, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.057953, Train accuracy: 91.33%
#          - Test loss: 0.140465, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.059354, Train accuracy: 93.33%
#          - Test loss: 0.139334, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.050983, Train accuracy: 95.33%
#          - Test loss: 0.140242, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.054186, Train accuracy: 92.67%
#          - Test loss: 0.139315, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.065645, Train accuracy: 93.33%
#          - Test loss: 0.137859, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.062405, Train accuracy: 92.00%
#          - Test loss: 0.138197, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.059990, Train accuracy: 92.67%
#          - Test loss: 0.136720, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.054997, Train accuracy: 92.67%
#          - Test loss: 0.137632, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.060727, Train accuracy: 88.00%
#          - Test loss: 0.137309, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.061155, Train accuracy: 91.33%
#          - Test loss: 0.137110, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.051797, Train accuracy: 94.67%
#          - Test loss: 0.137476, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.050619, Train accuracy: 94.00%
#          - Test loss: 0.136078, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.046759, Train accuracy: 94.00%
#          - Test loss: 0.136737, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.057634, Train accuracy: 90.67%
#          - Test loss: 0.134966, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.044599, Train accuracy: 96.00%
#          - Test loss: 0.134880, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.048768, Train accuracy: 92.67%
#          - Test loss: 0.134580, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.052110, Train accuracy: 92.67%
#          - Test loss: 0.134547, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.047260, Train accuracy: 94.00%
#          - Test loss: 0.134416, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.051388, Train accuracy: 95.33%
#          - Test loss: 0.134191, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.047669, Train accuracy: 93.33%
#          - Test loss: 0.134678, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.052339, Train accuracy: 92.67%
#          - Test loss: 0.133878, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.051933, Train accuracy: 96.00%
#          - Test loss: 0.133485, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.047444, Train accuracy: 92.67%
#          - Test loss: 0.133412, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.042283, Train accuracy: 94.00%
#          - Test loss: 0.133126, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.055060, Train accuracy: 90.67%
#          - Test loss: 0.133351, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.047042, Train accuracy: 93.33%
#          - Test loss: 0.131648, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.049093, Train accuracy: 93.33%
#          - Test loss: 0.131520, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.044384, Train accuracy: 92.67%
#          - Test loss: 0.131241, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.039701, Train accuracy: 92.67%
#          - Test loss: 0.131844, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.045439, Train accuracy: 93.33%
#          - Test loss: 0.131497, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.046724, Train accuracy: 94.00%
#          - Test loss: 0.131480, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.041885, Train accuracy: 95.33%
#          - Test loss: 0.130853, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.040738, Train accuracy: 94.00%
#          - Test loss: 0.130937, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.053033, Train accuracy: 92.67%
#          - Test loss: 0.131340, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.045330, Train accuracy: 94.67%
#          - Test loss: 0.131012, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.034929, Train accuracy: 94.67%
#          - Test loss: 0.130107, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.043501, Train accuracy: 96.67%
#          - Test loss: 0.129594, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.036535, Train accuracy: 96.00%
#          - Test loss: 0.129649, Test accuracy: 77.50%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)
